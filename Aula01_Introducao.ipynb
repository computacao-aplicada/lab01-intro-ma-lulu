# %% [markdown]
# <a href="https://colab.research.google.com/github/computacao-aplicada/lab01-intro-ma-lulu/blob/main/Aula01_Introducao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01: Introdução à Visão Computacional e Computação Gráfica
#
# ### 🎯 Objetivos da Aula
# - Compreender o que é Visão Computacional.
# - Diferenciar Visão Computacional, Processamento de Imagens e Computação Gráfica.
# - Realizar manipulações simples com imagens.
# - Explorar conceitos de pixels, resoluções e canais de cor.

# %% [markdown]
# ## O que é Visão Computacional?
#
# A **Visão Computacional** é uma área da Inteligência Artificial que busca permitir que os computadores 'vejam' e interpretem o mundo visual, assim como os humanos.
#
# Ela utiliza imagens e vídeos como entrada e tenta extrair informações úteis, como:
# - Detecção de objetos
# - Reconhecimento facial
# - Segmentação de imagem
# - Rastreamento de movimento
#
# A **Computação Gráfica**, por outro lado, está mais voltada à geração de imagens — como renderizar cenas em 3D.
#
# Já o **Processamento de Imagens** se concentra na transformação e análise de imagens (normalmente 2D) para melhorar a qualidade ou extrair características.
#
# | Área                  | Foco                             |
# |-----------------------|----------------------------------|
# | Visão Computacional   | Entendimento e interpretação     |
# | Computação Gráfica    | Geração de imagens               |
# | Processamento de Imagens | Manipulação e melhoria de imagens |

# %%
# Importação das bibliotecas necessárias
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Exibir gráficos inline
# %matplotlib inline

# %% [markdown]
# ## Exemplo prático: Carregar e visualizar uma imagem

# %%
# Carregar imagem de exemplo
from PIL import Image
import requests

url ="https://images.unsplash.com/photo-1742201949705-220268ad4467?q=80&w=1528&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"
image = Image.open(requests.get(url, stream=True).raw)
image = image.convert("RGB")  # Garante 3 canais

# Mostrar imagem
plt.imshow(image)
plt.title("Imagem Original")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Manipulação dos canais RGB

# %%
# Separar os canais
r, g, b = image.split()

# Exibir os canais
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for ax, channel, color in zip(axs, [r, g, b], ['R', 'G', 'B']):
    ax.imshow(channel, cmap='gray')
    ax.set_title(f'Canal {color}')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conversão para escala de cinza

# %%
# Converter para escala de cinza
gray_image = image.convert("L")

# Mostrar imagem em tons de cinza
plt.imshow(gray_image, cmap='gray')
plt.title("Imagem em Escala de Cinza")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Explorando os pixels

# %%
# Converter para numpy e mostrar valor de alguns pixels
np_image = np.array(image)
print("Formato da imagem:", np_image.shape)
print("Valor do pixel (0, 0):", np_image[0, 0])
# Out:
# Formato da imagem: (1910, 1528, 3)
# Valor do pixel (0, 0): [12 12 12]

# %% [markdown]
# ## 🧠 Exercício
#
# Tente modificar o código acima para:
#
# - Exibir apenas o canal vermelho da imagem.
# - Modifique aleatoriamente o canal vermelho e gere a imagem novamente.
# - Criar uma imagem negativa (inverter as cores).
# - Salvar uma nova imagem modificada no disco.
# - Recorte um pedaço da imagem e salve em disco.
#
# ---
# Cada um dos pontos do exercício deve ser uma célula separada!

# %% [markdown]
# #### Exercícios

# %% [markdown]
# ##### Exercício 1

# %%
# Ex.1 Exibir apenas o canal vermelho da imagem.

# Separar os canais
r, g, b = image.split()

# Exibir os canais
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for ax, channel, color in zip(axs, [r, g, b], ['R', 'G', 'B']):
    ax.imshow(channel, cmap='Reds')
    ax.set_title(f'Canal {color}')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Exercício 2

# %%
# Ex.2 Modifique aleatoriamente o canal vermelho e gere a imagem novamente.

np_image = np.array(image)
np_image[:, :, 0] = np.clip(np_image[:, :, 0] * 1.5, 50, 255)  # Aumenta R

# Exibir
plt.figure(figsize=(12, 6))
plt.subplot(121); plt.imshow(image); plt.title("Original")
plt.subplot(122); plt.imshow(np_image); plt.title("Canal R modificado")
plt.show()

# %% [markdown]
# ##### Exercício 3

# %%
# Ex.3 Criar uma imagem negativa (inverter as cores).

img_array = np.array(image)

# Inverter todos os canais (R, G, B)
img_invertida = 255 - img_array

# Converter de volta para imagem
img_final = Image.fromarray(img_invertida)

# Exibir comparação
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs[0].imshow(image)
axs[0].set_title("Original")
axs[1].imshow(img_final)
axs[1].set_title("Negativo da Imagem")
plt.show()

# %% [markdown]
# ##### Exercício 4

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

url ="https://images.unsplash.com/photo-1742201949705-220268ad4467?q=80&w=1528&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"
image = Image.open(requests.get(url, stream=True).raw)

# 2. Converter para escala de cinza
gray_image = image.convert("L")

# 3. Salvar imagem modificada
gray_image.save("imagem_em_cinza.jpg")  # salva no mesmo diretório

print("Imagem modificada salva com sucesso no disco!")

# !ls
# Out:
# Imagem modificada salva com sucesso no disco!
# imagem_em_cinza.jpg  recorte.jpg  sample_data

# %% [markdown]
# ##### Exercício 5

# %%
# Ex.5 Recorte um pedaço da imagem e salve em disco.
from PIL import Image
import requests
from IPython.display import display, FileLink

url = "https://images.unsplash.com/photo-1742201949705-220268ad4467?q=80&w=1528&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"  # Insira a URL da imagem aqui
image = Image.open(requests.get(url, stream=True).raw)

# 2. Definir a região de recorte (esquerda, superior, direita, inferior)
left = (800 - 400) // 2
top = (600 - 400) // 2
right = left + 400
bottom = top + 400
regiao_recorte = (left, top, right, bottom)

# 3. Recortar a imagem
imagem_recortada = image.crop(regiao_recorte)

# 4. Salvar o recorte
imagem_recortada.save("recorte.jpg")

# 5. Resultado
display(imagem_recortada)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
# /content/recorte.jpg
# imagem_em_cinza.jpg  recorte.jpg  sample_data
